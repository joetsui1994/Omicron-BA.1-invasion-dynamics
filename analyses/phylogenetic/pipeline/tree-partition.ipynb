# %% [markdown]
# ### Load in modules

# %%
from ete3 import Tree
import pandas as pd
import json
import copy
import copy

# %% [markdown]
# ### Load in data

# %%
tree_path = './final.matOptimize.rerooted.pruned.nh'
label_path = './seq_pango_comparison.tsv'

## function to reduce PANGO lvl
def lin_reduce(lin, lvl=3):
    return '.'.join(lin.split('.')[:lvl])

## load in tree and annotations
tree = Tree(tree_path, format=1)
grping_df = pd.read_csv(label_path, sep='\t')
grping = dict(zip(grping_df.seqName.values, [lin_reduce(x) for x in grping_df.new.values]))

# %% [markdown]
# ### Prep and label tree

# %%
tree_copy = tree.copy('newick-extended')
tree_grp_dist = {}

for node in tree_copy.traverse():
    depth = tree_copy.get_distance(node, topology_only=True)
    if node.is_leaf():
        leaf_grp = grping[node.name]
        node.add_features(grp=leaf_grp, depth=depth)
        if leaf_grp in tree_grp_dist:
            tree_grp_dist[leaf_grp]['count'] += 1
            if tree_grp_dist[leaf_grp]['depth'] > depth: tree_grp_dist[leaf_grp]['depth']  = depth
        else:
            tree_grp_dist[leaf_grp] = { 'count': 1, 'depth': depth }
    else:
        node.add_features(depth=depth)
    
print('Taxa count: %d' % len(tree_copy.get_leaves()))
# Out:
# Taxa count: 115622

# %%
## instead of traverse path from every foreign leaf to the MRCA, check for monophyletic groups
## for each monophyletic group (where exists), traverse from the top-most leaf in the group
def get_top_leaf(tree):
    if tree.is_leaf():
        return tree
    
    for node in tree.iter_descendants('levelorder'):
        if node.is_leaf():
            return node

# %%
DEFAULT_PARAMS = {
    'n_g_min': 10,
    'alpha': 0.6,
    'rho_f_max': 0.25,
    'rho_g_w': 0.6,
    'major_prop_min': 0.8,
    'minor_show_max': 3,
    'global_prop_indicate': {
        1.0: '*',
        0.9: '++',
        0.8: '+'
    }
}

# %%
####################     partition class     ####################

class Partition():
    
    def __init__(self, refs, root_node, params=DEFAULT_PARAMS):
        self.refs = { 'tree': refs['tree'], 'grp_dist': refs['grp_dist'] }
        self.actives = {'tree': root_node } ## need to create actives first to call on calc_grp_dist()
        self.actives['grp_dist'] = self.calc_grp_dist()
        self.count = len(root_node.get_leaves())
        self.is_candidate = True
        self.params = params
        self.set_name_partition()
        
        self.tree_up = root_node.up.name if root_node.up else None
        self.tree_up_dist = root_node.dist if root_node.up else 0
        
        
    def validate(self):
        ref_root_node = self.refs['tree'].search_nodes(name=self.actives['tree'].name)[0]
        ref_root_anc_node = ref_root_node.up if not ref_root_node.is_root() else None
        self.actives['tree'] = ref_root_node.detach()
        self.set_name_partition()
        self.update_ref_grp_dist()
        self.is_candidate = False

        ## strip remaining ref_tree of naked internal nodes
        if ref_root_anc_node:
            for leaf in ref_root_anc_node.iter_leaves():
                curr = leaf
                while curr.is_leaf() and not curr.is_root() and not hasattr(curr, 'grp'):
                    prev = curr
                    curr = curr.up
                    prev.detach()
                            
        
    def is_root(self):
        return self.actives['tree'].is_root()

        
    def get_leaves(self, grp_name=None, count_only=False, n_g_min_aware=False):        
        sf_leaves = sorted(list(filter(lambda leaf: (not grp_name or leaf.grp == grp_name) and \
                                       (not n_g_min_aware or self.refs['grp_dist'][leaf.grp]['count'] >= self.params['n_g_min']), \
                                       self.actives['tree'].get_leaves())), key=lambda leaf: leaf.depth, reverse=True)

        return (len(sf_leaves) if count_only else sf_leaves)
        
        
    def calc_grp_dist(self):
        grp_dist = {}
        for leaf in self.actives['tree'].iter_leaves():
            grp = leaf.grp
            depth = leaf.depth
            if grp in grp_dist:
                grp_dist[grp]['count'] += 1
                if depth > leaf.depth:
                    grp_dist[grp]['depth'] = leaf.depth
            else:
                grp_dist[grp] = { 'count': 1, 'depth': leaf.depth }
                    
        return grp_dist
    
    
    ## get majority grp (for naming)
    def get_majority_grp(self):
        sorted_grp_dist = self.sort_grp_dist(sort_by='size')
        return sorted_grp_dist[0]
    
    
    ## get sorted grp dist
    def sort_grp_dist(self, ref=False, sort_by='depth', n_g_min_aware=False):
        grp_dist = self.refs['grp_dist'] if ref else self.actives['grp_dist']
        pre_sort = [{ 'name': k, 'count': v['count'], 'depth': v['depth'] } for k, v in grp_dist.items()]
        
        if n_g_min_aware:
            pre_sort = list(filter(lambda grp: grp['count'] >= self.params['n_g_min'], pre_sort))
        
        sorted_by_size = sorted(pre_sort, key=lambda grp: grp['count'], reverse=sort_by == 'size')
        if sort_by == 'size':
            return sorted_by_size
        else:
            sorted_by_depth = sorted(sorted_by_size, key=lambda grp: grp['depth'], reverse=True)
            return sorted_by_depth
    
    
    ## get labelling name
    def set_name_partition(self):
        
        def modify_grp_name(grp):
            global_prop = grp['count']/tree_grp_dist[grp['name']]['count']
            for thres in self.params['global_prop_indicate'].keys():
                if global_prop >= thres:
                    return (grp['name'] + self.params['global_prop_indicate'][thres])

            return grp['name']
        
        sorted_grp_dist = self.sort_grp_dist(sort_by='size')
        
        is_single_majority = sorted_grp_dist[0]['count']/self.count >= self.params['major_prop_min']
        majority_grps = []
        minority_grps = []
        for grp in sorted_grp_dist:
            grp_prop = grp['count']/self.count
            if grp_prop >= self.params['major_prop_min']:
                majority_grps.append(grp)
            elif grp_prop < (1 - self.params['major_prop_min']):
                minority_grps.append(grp)
            else:
                if is_single_majority:
                    minority_grps.append(grp)
                else:
                    majority_grps.append(grp)
        
        majority_label = '/'.join([modify_grp_name(grp) for grp in majority_grps]) + \
                        ('/' if not is_single_majority and len(majority_grps) == 1 else '')
        minority_label = '(%s%s%s)' % ('/'.join([modify_grp_name(grp) for grp in minority_grps[:self.params['minor_show_max']]]), \
                        ('/...' if len(minority_grps) > self.params['minor_show_max'] else ''), \
                        ('[n=%d]' % len(minority_grps) if len(minority_grps) > self.params['minor_show_max'] else ''))
        
        self.name = (majority_label + (minority_label if len(minority_grps) else ''))
                
    
    def update_ref_grp_dist(self):
        for k, v in self.actives['grp_dist'].items():
            self.refs['grp_dist'][k]['count'] -= v['count']
            if self.refs['grp_dist'][k]['count'] == 0:
                del self.refs['grp_dist'][k]
            
            
    def calc_grp_obj(self, grp_name):
        n_g = self.actives['grp_dist'][grp_name]['count']
        n_c = self.get_leaves(count_only=True, n_g_min_aware=True)
        N_g = self.refs['grp_dist'][grp_name]['count']
        rho_c = n_g/n_c
        rho_g = n_g/N_g
                
        g_thres = n_g >= self.params['n_g_min']
        f_thres = (n_c - n_g) <= n_c*self.params['rho_f_max']*(1+rho_g*self.params['rho_g_w'])
        obj = self.params['alpha']*rho_c + (1 - self.params['alpha'])*rho_g
        
#         print(g_thres, n_g, self.params['n_g_min'])
#         print(f_thres, (n_c - n_g)/n_c, self.params['rho_f_max']*(1+rho_g*self.params['rho_g_w']), obj)
        
        return (g_thres and f_thres, obj)
            
            
    def find_partition(self, grp_name, node=None, starting_leaf=None):

        ## get farthest leaf in grp of interest
        root_node = node if node else self.refs['tree']
        grp_leaves = root_node.search_nodes(grp=grp_name)
        grp_mrca = root_node.get_common_ancestor(grp_leaves)
        depth_sorted_leaves = sorted(grp_leaves, key=lambda leaf: leaf.depth, reverse=True)
        
        ## start from deepest leaf, if no valid partition can be found then move onto to next deepest leaf
        iter_n = 10
        for i in range(min(iter_n, len(depth_sorted_leaves))):
            target_leaf = starting_leaf if starting_leaf else depth_sorted_leaves[i]

            ## evaluate obj as the path to the MRCA is traversed
            curr = target_leaf.up
            max_obj = -999
            max_obj_partition = None

            while True:
                curr_partition = Partition(self.refs, curr)
                pass_obj = curr_partition.calc_grp_obj(grp_name)

                if pass_obj[0] and pass_obj[1] >= max_obj:
                    max_obj_partition = curr_partition
                    max_obj_partition.obj = pass_obj[1]
                    max_obj = pass_obj[1]

                if curr.name == grp_mrca.name: break
                else: curr = curr.up
    #                 print(curr.name)

    #         print(max_obj)

            if starting_leaf or max_obj_partition:
                return max_obj_partition

        return None
    
    
    def check_foreign_partition(self, focus_grp):
        
        fgn_sorted_grps = filter(lambda grp: grp['name'] != focus_grp, 
                                 self.sort_grp_dist(sort_by='depth', n_g_min_aware=True))
        for grp in fgn_sorted_grps:
                        
            mono_leaves = map(lambda mono: get_top_leaf(mono),
                                 self.actives['tree'].get_monophyletic(values=[grp['name']], target_attr='grp'))            
            
            for leaf in mono_leaves:
                fgn_candidate = self.find_partition(grp['name'],
                                                    node=self.actives['tree'],
                                                    starting_leaf=leaf)

                if fgn_candidate:
                    return (fgn_candidate, grp['name'])

# %%
refs = { 'tree': tree_copy.copy('newick-extended'), 'grp_dist': copy.deepcopy(tree_grp_dist) }
ref_partition = Partition(refs, tree_copy.copy('newick-extended'))

# %%
## main program starts here

partitions = []

start_time = time.time()
while True:
    
    print('Calculating most updated grp distribution...')
    depth_sorted_grps = ref_partition.sort_grp_dist(ref=True, sort_by='depth', n_g_min_aware=True)
    
    remaining_grp_exists = len(depth_sorted_grps)
    for grp in depth_sorted_grps:
                
        partition_stored = False
        focus_grp = grp['name']
        
        print(focus_grp)
        
        partition_candidate = ref_partition.find_partition(focus_grp)
        
        while partition_candidate:
            
            print('focus_grp: ', focus_grp)
            fgn_candidate = partition_candidate.check_foreign_partition(focus_grp)
            
            if fgn_candidate:
                partition_candidate, focus_grp = fgn_candidate
                
                continue
                
            else:
                partition_candidate.validate()
                partitions.append(partition_candidate)
                partition_stored = True

                print('\n%d' % (len(partitions) + 1))
                print(partition_candidate.name)
                print(partition_candidate.actives['tree'].name)
                print(partition_candidate.actives['grp_dist'])
                
                break
        
        if partition_stored:
            break ## break out to update global group distribution
    
    else:
        if remaining_grp_exists:
            continue
        else:
            break
            
print(time.time() - start_time)
# Out:
# Calculating most updated grp distribution...
# BA.1.15
# focus_grp:  BA.1.15
#
# 2
# BA.1.15
# node_11356
# {'BA.1.15': {'count': 22, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# focus_grp:  BA.1.15
#
# 3
# BA.1.15++(BA.1)
# node_15136
# {'BA.1.15': {'count': 12222, 'depth': '12.0'}, 'BA.1': {'count': 7, 'depth': '16.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.2.22
# focus_grp:  BA.2.22
#
# 4
# BA.2.22*(BA.2)
# node_18103
# {'BA.2.22': {'count': 39, 'depth': '7.0'}, 'BA.2': {'count': 1, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.8
# focus_grp:  BA.1.8
#
# 5
# BA.1.8*
# node_14341
# {'BA.1.8': {'count': 46, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.5
# focus_grp:  BA.1.5
#
# 6
# BA.1.5*
# node_14305
# {'BA.1.5': {'count': 81, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.12
# focus_grp:  BA.1.12
#
# 7
# BA.1.12++(BA.1)
# node_497
# {'BA.1.12': {'count': 292, 'depth': '8.0'}, 'BA.1': {'count': 4, 'depth': '10.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.12
# focus_grp:  BA.1.12
#
# 8
# BA.1.12
# node_4374
# {'BA.1.12': {'count': 13, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.20
# focus_grp:  BA.1.20
#
# 9
# BA.1.20++(BA.1/BA.1.15)
# node_14477
# {'BA.1.20': {'count': 1167, 'depth': '8.0'}, 'BA.1': {'count': 22, 'depth': '8.0'}, 'BA.1.15': {'count': 1, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# focus_grp:  BA.1.16
#
# 10
# BA.1.16
# node_4661
# {'BA.1.16': {'count': 29, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# focus_grp:  BA.1.16
#
# 11
# BA.1.16++(BA.1/BA.1.18/BA.1.21)
# node_11885
# {'BA.1.16': {'count': 1740, 'depth': '9.0'}, 'BA.1': {'count': 10, 'depth': '9.0'}, 'BA.1.18': {'count': 1, 'depth': '11.0'}, 'BA.1.21': {'count': 1, 'depth': '11.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.2.12
# focus_grp:  BA.2.12
#
# 12
# BA.2.12*
# node_18367
# {'BA.2.12': {'count': 10, 'depth': '6.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.2.13
# BA.1.6
# focus_grp:  BA.1.6
#
# 13
# BA.1.6(BA.1)
# node_14274
# {'BA.1.6': {'count': 21, 'depth': '7.0'}, 'BA.1': {'count': 1, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.2.13
# BA.1.4
# focus_grp:  BA.1.4
#
# 14
# BA.1.4+
# node_14263
# {'BA.1.4': {'count': 27, 'depth': '6.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.2.13
# BA.2.2
# focus_grp:  BA.2.2
#
# 15
# BA.2.2*
# node_18482
# {'BA.2.2': {'count': 51, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.2.13
# BA.1.9
# focus_grp:  BA.1.9
#
# 16
# BA.1.9(BA.1)
# node_14323
# {'BA.1.9': {'count': 51, 'depth': '7.0'}, 'BA.1': {'count': 5, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.2.13
# BA.1.9
# focus_grp:  BA.1.9
#
# 17
# BA.1.9
# node_12604
# {'BA.1.9': {'count': 14, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.7
# focus_grp:  BA.1.7
#
# 18
# BA.1.7
# node_4705
# {'BA.1.7': {'count': 11, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.7
# focus_grp:  BA.1.7
#
# 19
# BA.1.7+(BA.1)
# node_14382
# {'BA.1.7': {'count': 109, 'depth': '6.0'}, 'BA.1': {'count': 1, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.7
# BA.1.9
# BA.2.13
# BA.2.3
# focus_grp:  BA.2.3
#
# 20
# BA.2.3*(BA.2)
# node_18402
# {'BA.2.3': {'count': 223, 'depth': '6.0'}, 'BA.2': {'count': 1, 'depth': '6.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.7
# BA.1.9
# BA.2.13
# BA.1.10
# focus_grp:  BA.1.10
#
# 21
# BA.1.10+(BA.1)
# node_141
# {'BA.1.10': {'count': 233, 'depth': '6.0'}, 'BA.1': {'count': 2, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.7
# BA.1.9
# BA.2.13
# BA.1.10
# focus_grp:  BA.1.10
#
# 22
# BA.1.10
# node_5019
# {'BA.1.10': {'count': 44, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.7
# BA.1.9
# BA.2.13
# BA.1.19
# focus_grp:  BA.1.19
#
# 23
# BA.1.19++(BA.1)
# node_3831
# {'BA.1.19': {'count': 326, 'depth': '7.0'}, 'BA.1': {'count': 1, 'depth': '6.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.7
# BA.1.9
# BA.2.13
# BA.1.19
# BA.1.21
# focus_grp:  BA.1.21
#
# 24
# BA.1.21++(BA.1/BA.1.1/BA.1.7)
# node_46
# {'BA.1.21': {'count': 465, 'depth': '6.0'}, 'BA.1': {'count': 4, 'depth': '8.0'}, 'BA.1.1': {'count': 1, 'depth': '8.0'}, 'BA.1.7': {'count': 1, 'depth': '6.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.2.10
# focus_grp:  BA.2.10
#
# 25
# BA.2.10++(BA.2/BA.2.23)
# node_18257
# {'BA.2.10': {'count': 528, 'depth': '6.0'}, 'BA.2': {'count': 1, 'depth': '10.0'}, 'BA.2.23': {'count': 1, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.13
# focus_grp:  BA.1.13
#
# 26
# BA.1.13++(BA.1)
# node_4267
# {'BA.1': {'count': 5, 'depth': '7.0'}, 'BA.1.13': {'count': 744, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.2.9
# focus_grp:  BA.2.9
#
# 27
# BA.2.9++(BA.2)
# node_17720
# {'BA.2.9': {'count': 1052, 'depth': '6.0'}, 'BA.2': {'count': 3, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# focus_grp:  BA.1.18
#
# 28
# BA.1.18
# node_4652
# {'BA.1.18': {'count': 19, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# focus_grp:  BA.1.18
#
# 29
# BA.1.18++(BA.1)
# node_4753
# {'BA.1.18': {'count': 2246, 'depth': '6.0'}, 'BA.1': {'count': 7, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# focus_grp:  BA.1.18
#
# 30
# BA.1.18
# node_17636
# {'BA.1.18': {'count': 19, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.2.1
# focus_grp:  BA.2.1
#
# 31
# BA.2.1++
# node_18473
# {'BA.2.1': {'count': 64, 'depth': '5.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# focus_grp:  BA.1.17
#
# 32
# BA.1.17
# node_9
# {'BA.1.17': {'count': 12, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# focus_grp:  BA.1.17
#
# 33
# BA.1.17
# node_450
# {'BA.1.17': {'count': 15, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# focus_grp:  BA.1.17
#
# 34
# BA.1.17++(BA.1/BA.1.1/BA.1.15/...[n=8])
# node_664
# {'BA.1.17': {'count': 21469, 'depth': '7.0'}, 'BA.1': {'count': 48, 'depth': '12.0'}, 'BA.1.1': {'count': 15, 'depth': '13.0'}, 'BA.1.15': {'count': 8, 'depth': '10.0'}, 'BA.1.20': {'count': 1, 'depth': '11.0'}, 'BA.1.19': {'count': 2, 'depth': '9.0'}, 'BA.1.6': {'count': 2, 'depth': '6.0'}, 'BA.1.18': {'count': 3, 'depth': '10.0'}, 'BA.1.9': {'count': 1, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# focus_grp:  BA.1.14
#
# 35
# BA.1.14++(BA.1)
# node_561
# {'BA.1.14': {'count': 575, 'depth': '6.0'}, 'BA.1': {'count': 7, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# focus_grp:  BA.1.14
#
# 36
# BA.1.14
# node_33
# {'BA.1.14': {'count': 10, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
#
# 37
# BA.1.1
# node_4391
# {'BA.1.1': {'count': 1498, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
# focus_grp:  BA.1
#
# 38
# BA.1(BA.1.1)
# node_5223
# {'BA.1': {'count': 21, 'depth': '9.0'}, 'BA.1.1': {'count': 1, 'depth': '10.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
# focus_grp:  BA.1
#
# 39
# BA.1(BA.1.1)
# node_5642
# {'BA.1': {'count': 38, 'depth': '11.0'}, 'BA.1.1': {'count': 6, 'depth': '13.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.21
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
# focus_grp:  BA.1
#
# 40
# BA.1/(BA.1.17/BA.1.21)
# node_6053
# {'BA.1': {'count': 15, 'depth': '18.0'}, 'BA.1.17': {'count': 2, 'depth': '16.0'}, 'BA.1.21': {'count': 2, 'depth': '17.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.1.21
# BA.2.13
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
# focus_grp:  BA.1
#
# 41
# BA.1(BA.1.1)
# node_6079
# {'BA.1': {'count': 38, 'depth': '10.0'}, 'BA.1.1': {'count': 4, 'depth': '10.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.1.21
# BA.2.13
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
# focus_grp:  BA.1
#
# 42
# BA.1
# node_8711
# {'BA.1': {'count': 17, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.1.21
# BA.2.13
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
# focus_grp:  BA.1
#
# 43
# BA.1(BA.1.17/BA.1.16/BA.1.21/...[n=4])
# node_11404
# {'BA.1': {'count': 46, 'depth': '9.0'}, 'BA.1.16': {'count': 3, 'depth': '11.0'}, 'BA.1.21': {'count': 1, 'depth': '9.0'}, 'BA.1.17': {'count': 4, 'depth': '10.0'}, 'BA.1.18': {'count': 1, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.15
# BA.1.16
# BA.1.9
# BA.1.21
# BA.2.13
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
#
# 44
# BA.1.1++(BA.1/BA.1.15/BA.1.18/...[n=8])
# node_5153
# {'BA.1.1': {'count': 36621, 'depth': '9.0'}, 'BA.1': {'count': 167, 'depth': '11.0'}, 'BA.1.15': {'count': 10, 'depth': '11.0'}, 'BA.1.18': {'count': 2, 'depth': '10.0'}, 'BA.1.21': {'count': 2, 'depth': '11.0'}, 'BA.1.14': {'count': 2, 'depth': '11.0'}, 'XP': {'count': 1, 'depth': '8.0'}, 'BA.1.10': {'count': 1, 'depth': '7.0'}, 'BA.1.19': {'count': 1, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# focus_grp:  BA.1.1
#
# 45
# BA.1.1
# node_14282
# {'BA.1.1': {'count': 42, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.9
# BA.2.13
# BA.1.19
# BA.1.18
# BA.2.23
# BA.1.17
# BA.1.14
# BA.1.1
# BA.2
# focus_grp:  BA.2
#
# 46
# BA.2++(BA.2.13*/BA.2.23++/BA.2.5*/...[n=16])
# node_17695
# {'BA.2': {'count': 4254, 'depth': '1.0'}, 'BA.2.16': {'count': 6, 'depth': '6.0'}, 'BA.2.19': {'count': 6, 'depth': '6.0'}, 'BA.2.25': {'count': 1, 'depth': '6.0'}, 'BA.2.6': {'count': 1, 'depth': '5.0'}, 'BA.2.13': {'count': 12, 'depth': '8.0'}, 'BA.2.7': {'count': 1, 'depth': '5.0'}, 'BA.2.34': {'count': 1, 'depth': '5.0'}, 'BA.2.23': {'count': 10, 'depth': '6.0'}, 'BA.2.10': {'count': 6, 'depth': '8.0'}, 'BA.2.31': {'count': 2, 'depth': '5.0'}, 'BA.2.1': {'count': 2, 'depth': '6.0'}, 'BA.2.5': {'count': 7, 'depth': '5.0'}, 'BA.2.4': {'count': 5, 'depth': '5.0'}, 'BA.2.28': {'count': 3, 'depth': '5.0'}, 'BA.2.27': {'count': 1, 'depth': '4.0'}, 'BA.2.9': {'count': 2, 'depth': '6.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.9
# BA.1.19
# BA.1.18
# BA.1.17
# BA.1.14
# BA.1.1
# BA.1
# focus_grp:  BA.1
# focus_grp:  BA.1.1
#
# 47
# BA.1.1
# node_111
# {'BA.1.1': {'count': 73, 'depth': '11.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.9
# BA.1.19
# BA.1.18
# BA.1.17
# BA.1.14
# BA.1.1
# BA.1
# focus_grp:  BA.1
# focus_grp:  BA.1.1
#
# 48
# BA.1.1(BA.1/BA.1.9/BA.1.17/...[n=5])
# node_14817
# {'BA.1': {'count': 35, 'depth': '9.0'}, 'BA.1.1': {'count': 919, 'depth': '10.0'}, 'BA.1.17': {'count': 1, 'depth': '10.0'}, 'BA.1.9': {'count': 2, 'depth': '10.0'}, 'BA.1.10': {'count': 1, 'depth': '9.0'}, 'BA.1.6': {'count': 1, 'depth': '9.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.19
# BA.1.18
# BA.1.17
# BA.1.14
# BA.1.1
# BA.1
# focus_grp:  BA.1
# focus_grp:  BA.1.17
#
# 49
# BA.1.17
# node_410
# {'BA.1.17': {'count': 17, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.19
# BA.1.18
# BA.1.17
# BA.1.14
# BA.1.1
# BA.1
# focus_grp:  BA.1
# focus_grp:  BA.1.17
#
# 50
# BA.1.17
# node_5141
# {'BA.1.17': {'count': 14, 'depth': '8.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.19
# BA.1.18
# BA.1.17
# BA.1.14
# BA.1.1
# BA.1
# focus_grp:  BA.1
# focus_grp:  BA.1.17
#
# 51
# BA.1.17
# node_17640
# {'BA.1.17': {'count': 23, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# BA.1.16
# BA.1.19
# BA.1.18
# BA.1.17
# BA.1.14
# BA.1.1
# BA.1
# focus_grp:  BA.1
#
# 52
# BA.1++(BA.1.1/BA.1.17/BA.1.14/...[n=18])
# node_6
# {'BA.1': {'count': 27267, 'depth': '5.0'}, 'BA.1.19': {'count': 15, 'depth': '6.0'}, 'BA.1.1': {'count': 62, 'depth': '7.0'}, 'BA.1.10': {'count': 7, 'depth': '6.0'}, 'BA.1.16': {'count': 14, 'depth': '11.0'}, 'BA.1.17': {'count': 37, 'depth': '10.0'}, 'BA.1.9': {'count': 8, 'depth': '10.0'}, 'BA.1.21': {'count': 9, 'depth': '10.0'}, 'BA.1.7': {'count': 9, 'depth': '9.0'}, 'BA.1.13': {'count': 8, 'depth': '10.0'}, 'BA.1.18': {'count': 15, 'depth': '8.0'}, 'BA.1.6': {'count': 5, 'depth': '7.0'}, 'BA.1.14': {'count': 20, 'depth': '8.0'}, 'BA.1.4': {'count': 4, 'depth': '6.0'}, 'BA.1.15': {'count': 1, 'depth': '10.0'}, 'BA.1.3': {'count': 9, 'depth': '7.0'}, 'BA.1.20': {'count': 3, 'depth': '8.0'}, 'BA.1.2': {'count': 8, 'depth': '7.0'}, 'BA.1.12': {'count': 1, 'depth': '7.0'}}
# Calculating most updated grp distribution...
# 821.3550479412079

# %%
## rename partitions to ensure uniqueness
partition_names = []

count = 0
print('#partitions: %d\n' % len(partitions))
for i, p in enumerate(partitions):
    count += p.count
    name_count = partition_names.count(p.name)
    partition_names.append(p.name)
    if name_count:
        p.name = '%s_%d' % (p.name, name_count)
    print(i+1)
    print('%s\n%s' % (p.name, str(p.actives['grp_dist'])))
    print('\n')
    
print('#leaves: %d' % count)
# Out:
# #partitions: 51
#
# 1
# BA.1.15
# {'BA.1.15': {'count': 22, 'depth': '9.0'}}
#
#
# 2
# BA.1.15++(BA.1)
# {'BA.1.15': {'count': 12222, 'depth': '12.0'}, 'BA.1': {'count': 7, 'depth': '16.0'}}
#
#
# 3
# BA.2.22*(BA.2)
# {'BA.2.22': {'count': 39, 'depth': '7.0'}, 'BA.2': {'count': 1, 'depth': '9.0'}}
#
#
# 4
# BA.1.8*
# {'BA.1.8': {'count': 46, 'depth': '8.0'}}
#
#
# 5
# BA.1.5*
# {'BA.1.5': {'count': 81, 'depth': '7.0'}}
#
#
# 6
# BA.1.12++(BA.1)
# {'BA.1.12': {'count': 292, 'depth': '8.0'}, 'BA.1': {'count': 4, 'depth': '10.0'}}
#
#
# 7
# BA.1.12
# {'BA.1.12': {'count': 13, 'depth': '9.0'}}
#
#
# 8
# BA.1.20++(BA.1/BA.1.15)
# {'BA.1.20': {'count': 1167, 'depth': '8.0'}, 'BA.1': {'count': 22, 'depth': '8.0'}, 'BA.1.15': {'count': 1, 'depth': '9.0'}}
#
#
# 9
# BA.1.16
# {'BA.1.16': {'count': 29, 'depth': '9.0'}}
#
#
# 10
# BA.1.16++(BA.1/BA.1.18/BA.1.21)
# {'BA.1.16': {'count': 1740, 'depth': '9.0'}, 'BA.1': {'count': 10, 'depth': '9.0'}, 'BA.1.18': {'count': 1, 'depth': '11.0'}, 'BA.1.21': {'count': 1, 'depth': '11.0'}}
#
#
# 11
# BA.2.12*
# {'BA.2.12': {'count': 10, 'depth': '6.0'}}
#
#
# 12
# BA.1.6(BA.1)
# {'BA.1.6': {'count': 21, 'depth': '7.0'}, 'BA.1': {'count': 1, 'depth': '7.0'}}
#
#
# 13
# BA.1.4+
# {'BA.1.4': {'count': 27, 'depth': '6.0'}}
#
#
# 14
# BA.2.2*
# {'BA.2.2': {'count': 51, 'depth': '8.0'}}
#
#
# 15
# BA.1.9(BA.1)
# {'BA.1.9': {'count': 51, 'depth': '7.0'}, 'BA.1': {'count': 5, 'depth': '7.0'}}
#
#
# 16
# BA.1.9
# {'BA.1.9': {'count': 14, 'depth': '7.0'}}
#
#
# 17
# BA.1.7
# {'BA.1.7': {'count': 11, 'depth': '8.0'}}
#
#
# 18
# BA.1.7+(BA.1)
# {'BA.1.7': {'count': 109, 'depth': '6.0'}, 'BA.1': {'count': 1, 'depth': '8.0'}}
#
#
# 19
# BA.2.3*(BA.2)
# {'BA.2.3': {'count': 223, 'depth': '6.0'}, 'BA.2': {'count': 1, 'depth': '6.0'}}
#
#
# 20
# BA.1.10+(BA.1)
# {'BA.1.10': {'count': 233, 'depth': '6.0'}, 'BA.1': {'count': 2, 'depth': '8.0'}}
#
#
# 21
# BA.1.10
# {'BA.1.10': {'count': 44, 'depth': '7.0'}}
#
#
# 22
# BA.1.19++(BA.1)
# {'BA.1.19': {'count': 326, 'depth': '7.0'}, 'BA.1': {'count': 1, 'depth': '6.0'}}
#
#
# 23
# BA.1.21++(BA.1/BA.1.1/BA.1.7)
# {'BA.1.21': {'count': 465, 'depth': '6.0'}, 'BA.1': {'count': 4, 'depth': '8.0'}, 'BA.1.1': {'count': 1, 'depth': '8.0'}, 'BA.1.7': {'count': 1, 'depth': '6.0'}}
#
#
# 24
# BA.2.10++(BA.2/BA.2.23)
# {'BA.2.10': {'count': 528, 'depth': '6.0'}, 'BA.2': {'count': 1, 'depth': '10.0'}, 'BA.2.23': {'count': 1, 'depth': '8.0'}}
#
#
# 25
# BA.1.13++(BA.1)
# {'BA.1': {'count': 5, 'depth': '7.0'}, 'BA.1.13': {'count': 744, 'depth': '7.0'}}
#
#
# 26
# BA.2.9++(BA.2)
# {'BA.2.9': {'count': 1052, 'depth': '6.0'}, 'BA.2': {'count': 3, 'depth': '7.0'}}
#
#
# 27
# BA.1.18
# {'BA.1.18': {'count': 19, 'depth': '8.0'}}
#
#
# 28
# BA.1.18++(BA.1)
# {'BA.1.18': {'count': 2246, 'depth': '6.0'}, 'BA.1': {'count': 7, 'depth': '9.0'}}
#
#
# 29
# BA.1.18_1
# {'BA.1.18': {'count': 19, 'depth': '7.0'}}
#
#
# 30
# BA.2.1++
# {'BA.2.1': {'count': 64, 'depth': '5.0'}}
#
#
# 31
# BA.1.17
# {'BA.1.17': {'count': 12, 'depth': '8.0'}}
#
#
# 32
# BA.1.17_1
# {'BA.1.17': {'count': 15, 'depth': '8.0'}}
#
#
# 33
# BA.1.17++(BA.1/BA.1.1/BA.1.15/...[n=8])
# {'BA.1.17': {'count': 21469, 'depth': '7.0'}, 'BA.1': {'count': 48, 'depth': '12.0'}, 'BA.1.1': {'count': 15, 'depth': '13.0'}, 'BA.1.15': {'count': 8, 'depth': '10.0'}, 'BA.1.20': {'count': 1, 'depth': '11.0'}, 'BA.1.19': {'count': 2, 'depth': '9.0'}, 'BA.1.6': {'count': 2, 'depth': '6.0'}, 'BA.1.18': {'count': 3, 'depth': '10.0'}, 'BA.1.9': {'count': 1, 'depth': '7.0'}}
#
#
# 34
# BA.1.14++(BA.1)
# {'BA.1.14': {'count': 575, 'depth': '6.0'}, 'BA.1': {'count': 7, 'depth': '8.0'}}
#
#
# 35
# BA.1.14
# {'BA.1.14': {'count': 10, 'depth': '7.0'}}
#
#
# 36
# BA.1.1
# {'BA.1.1': {'count': 1498, 'depth': '9.0'}}
#
#
# 37
# BA.1(BA.1.1)
# {'BA.1': {'count': 21, 'depth': '9.0'}, 'BA.1.1': {'count': 1, 'depth': '10.0'}}
#
#
# 38
# BA.1(BA.1.1)_1
# {'BA.1': {'count': 38, 'depth': '11.0'}, 'BA.1.1': {'count': 6, 'depth': '13.0'}}
#
#
# 39
# BA.1/(BA.1.17/BA.1.21)
# {'BA.1': {'count': 15, 'depth': '18.0'}, 'BA.1.17': {'count': 2, 'depth': '16.0'}, 'BA.1.21': {'count': 2, 'depth': '17.0'}}
#
#
# 40
# BA.1(BA.1.1)_2
# {'BA.1': {'count': 38, 'depth': '10.0'}, 'BA.1.1': {'count': 4, 'depth': '10.0'}}
#
#
# 41
# BA.1
# {'BA.1': {'count': 17, 'depth': '9.0'}}
#
#
# 42
# BA.1(BA.1.17/BA.1.16/BA.1.21/...[n=4])
# {'BA.1': {'count': 46, 'depth': '9.0'}, 'BA.1.16': {'count': 3, 'depth': '11.0'}, 'BA.1.21': {'count': 1, 'depth': '9.0'}, 'BA.1.17': {'count': 4, 'depth': '10.0'}, 'BA.1.18': {'count': 1, 'depth': '9.0'}}
#
#
# 43
# BA.1.1++(BA.1/BA.1.15/BA.1.18/...[n=8])
# {'BA.1.1': {'count': 36621, 'depth': '9.0'}, 'BA.1': {'count': 167, 'depth': '11.0'}, 'BA.1.15': {'count': 10, 'depth': '11.0'}, 'BA.1.18': {'count': 2, 'depth': '10.0'}, 'BA.1.21': {'count': 2, 'depth': '11.0'}, 'BA.1.14': {'count': 2, 'depth': '11.0'}, 'XP': {'count': 1, 'depth': '8.0'}, 'BA.1.10': {'count': 1, 'depth': '7.0'}, 'BA.1.19': {'count': 1, 'depth': '8.0'}}
#
#
# 44
# BA.1.1_1
# {'BA.1.1': {'count': 42, 'depth': '8.0'}}
#
#
# 45
# BA.2++(BA.2.13*/BA.2.23++/BA.2.5*/...[n=16])
# {'BA.2': {'count': 4254, 'depth': '1.0'}, 'BA.2.16': {'count': 6, 'depth': '6.0'}, 'BA.2.19': {'count': 6, 'depth': '6.0'}, 'BA.2.25': {'count': 1, 'depth': '6.0'}, 'BA.2.6': {'count': 1, 'depth': '5.0'}, 'BA.2.13': {'count': 12, 'depth': '8.0'}, 'BA.2.7': {'count': 1, 'depth': '5.0'}, 'BA.2.34': {'count': 1, 'depth': '5.0'}, 'BA.2.23': {'count': 10, 'depth': '6.0'}, 'BA.2.10': {'count': 6, 'depth': '8.0'}, 'BA.2.31': {'count': 2, 'depth': '5.0'}, 'BA.2.1': {'count': 2, 'depth': '6.0'}, 'BA.2.5': {'count': 7, 'depth': '5.0'}, 'BA.2.4': {'count': 5, 'depth': '5.0'}, 'BA.2.28': {'count': 3, 'depth': '5.0'}, 'BA.2.27': {'count': 1, 'depth': '4.0'}, 'BA.2.9': {'count': 2, 'depth': '6.0'}}
#
#
# 46
# BA.1.1_2
# {'BA.1.1': {'count': 73, 'depth': '11.0'}}
#
#
# 47
# BA.1.1(BA.1/BA.1.9/BA.1.17/...[n=5])
# {'BA.1': {'count': 35, 'depth': '9.0'}, 'BA.1.1': {'count': 919, 'depth': '10.0'}, 'BA.1.17': {'count': 1, 'depth': '10.0'}, 'BA.1.9': {'count': 2, 'depth': '10.0'}, 'BA.1.10': {'count': 1, 'depth': '9.0'}, 'BA.1.6': {'count': 1, 'depth': '9.0'}}
#
#
# 48
# BA.1.17_2
# {'BA.1.17': {'count': 17, 'depth': '7.0'}}
#
#
# 49
# BA.1.17_3
# {'BA.1.17': {'count': 14, 'depth': '8.0'}}
#
#
# 50
# BA.1.17_4
# {'BA.1.17': {'count': 23, 'depth': '7.0'}}
#
#
# 51
# BA.1++(BA.1.1/BA.1.17/BA.1.14/...[n=18])
# {'BA.1': {'count': 27267, 'depth': '5.0'}, 'BA.1.19': {'count': 15, 'depth': '6.0'}, 'BA.1.1': {'count': 62, 'depth': '7.0'}, 'BA.1.10': {'count': 7, 'depth': '6.0'}, 'BA.1.16': {'count': 14, 'depth': '11.0'}, 'BA.1.17': {'count': 37, 'depth': '10.0'}, 'BA.1.9': {'count': 8, 'depth': '10.0'}, 'BA.1.21': {'count': 9, 'depth': '10.0'}, 'BA.1.7': {'count': 9, 'depth': '9.0'}, 'BA.1.13': {'count': 8, 'depth': '10.0'}, 'BA.1.18': {'count': 15, 'depth': '8.0'}, 'BA.1.6': {'count': 5, 'depth': '7.0'}, 'BA.1.14': {'count': 20, 'depth': '8.0'}, 'BA.1.4': {'count': 4, 'depth': '6.0'}, 'BA.1.15': {'count': 1, 'depth': '10.0'}, 'BA.1.3': {'count': 9, 'depth': '7.0'}, 'BA.1.20': {'count': 3, 'depth': '8.0'}, 'BA.1.2': {'count': 8, 'depth': '7.0'}, 'BA.1.12': {'count': 1, 'depth': '7.0'}}
#
#
# #leaves: 115622

# %% [markdown]
# ## Construct partition-tree

# %%
## need empty partition as root partition
root_partition_node = Tree(name='root', format=1)

i_nodes = {}
p_nodes = {}
for p in partitions:
    temp_t = Tree(name=p.name, format=1)
    temp_t.dist = p.tree_up_dist
    temp_t.add_features(p=p)
    p_nodes[p] = temp_t
    
for p, n in p_nodes.items():
    curr_up = tree_copy.search_nodes(name=p.tree_up)[0]
    curr_p_tree = n
    anc_found = False
    while not anc_found:
        for pp, nn in p_nodes.items():
            if curr_up.is_root():
                root_partition_node.add_child(curr_p_tree)
                anc_found = True
                break
            elif curr_up.name in i_nodes:
                i_nodes[curr_up.name] = i_nodes[curr_up.name].add_child(curr_p_tree)
                anc_found = True
                break
            elif pp.actives['tree'].search_nodes(name=curr_up.name):
                nn.add_child(curr_p_tree)
                anc_found = True
                break

        if not anc_found:
            anc_part = Tree(name=curr_up.name, format=1)
            anc_part.add_child(curr_p_tree)
            curr_p_tree = anc_part
            i_nodes[curr_p_tree.name] = curr_p_tree
                
        if not curr_up.is_root():
            curr_up = curr_up.up

# %%
for node in root_partition_node.traverse():
    if node.name.startswith('BA'):
        count = node.p.count
        node.name = '%s|N=%d' % (node.name, count)

# %%
print(root_partition_node.get_ascii())
# Out:
#                                                        /-BA.2.22*(BA.2)|N=40
#                                                       |
#                                                       |--BA.2.12*|N=10
#                                                       |
#                                                       |--BA.2.2*|N=51
#                                                       |
#     /BA.2++(BA.2.13*/BA.2.23++/BA.2.5*/...[n=16])|N=4320-BA.2.3*(BA.2)|N=224
#    |                                                  |
#    |                                                  |--BA.2.10++(BA.2/BA.2.23)|N=530
#    |                                                  |
#    |                                                  |--BA.2.9++(BA.2)|N=1055
#    |                                                  |
#    |                                                   \-BA.2.1++|N=64
#    |
#    |                                                /-BA.1.15++(BA.1)|N=12229
#    |                                               |
#    |                                               |--BA.1.8*|N=46
#    |                                               |
#    |                                               |--BA.1.5*|N=81
#    |                                               |
#    |                                               |--BA.1.12++(BA.1)|N=296
#    |                                               |
#    |                                               |--BA.1.12|N=13
#    |                                               |
#    |                                               |--BA.1.20++(BA.1/BA.1.15)|N=1190
#    |                                               |
#    |                                               |--BA.1.16|N=29
#    |                                               |
#    |                                               |--BA.1.16++(BA.1/BA.1.18/BA.1.21)|N=1752
# -root                                              |
#    |                                               |--BA.1.6(BA.1)|N=22
#    |                                               |
#    |                                               |--BA.1.4+|N=27
#    |                                               |
#    |                                               |--BA.1.9(BA.1)|N=56
#    |                                               |
#    |                                               |--BA.1.9|N=14
#    |                                               |
#    |                                               |--BA.1.7|N=11
#    |                                               |
#    |                                               |--BA.1.7+(BA.1)|N=110
#    |                                               |
#    |                                               |--BA.1.10+(BA.1)|N=235
#    |                                               |
#    |                                               |--BA.1.19++(BA.1)|N=327
#    |                                               |
#    |                                               |--BA.1.21++(BA.1/BA.1.1/BA.1.7)|N=471
#    |                                               |
#    |                                               |--BA.1.13++(BA.1)|N=749
#    |                                               |
#    |                                               |--BA.1.18|N=19
#    |                                               |
#    |                                               |-BA.1.18++(BA.1)|N=2253-BA.1.10|N=44
#     \BA.1++(BA.1.1/BA.1.17/BA.1.14/...[n=18])|N=27513
#                                                    |--BA.1.18_1|N=19
#                                                    |
#                                                    |--BA.1.17|N=12
#                                                    |
#                                                    |--BA.1.17_1|N=15
#                                                    |
#                                                    |--BA.1.17++(BA.1/BA.1.1/BA.1.15/...[n=8])|N=21549
#                                                    |
#                                                    |--BA.1.14++(BA.1)|N=582
#                                                    |
#                                                    |--BA.1.14|N=10
#                                                    |
#                                                    |--BA.1.1|N=1498
#                                                    |
#                                                    |                                               /-BA.1.15|N=22
#                                                    |                                              |
#                                                    |                                              |--BA.1(BA.1.1)|N=22
#                                                    |                                              |
#                                                    |                                              |--BA.1(BA.1.1)_1|N=44
#                                                    |                                              |
#                                                    |-BA.1.1++(BA.1/BA.1.15/BA.1.18/...[n=8])|N=36807-BA.1/(BA.1.17/BA.1.21)|N=19
#                                                    |                                              |
#                                                    |                                              |--BA.1(BA.1.1)_2|N=42
#                                                    |                                              |
#                                                    |                                              |--BA.1|N=17
#                                                    |                                              |
#                                                    |                                               \-BA.1(BA.1.17/BA.1.16/BA.1.21/...[n=4])|N=55
#                                                    |
#                                                    |--BA.1.1_1|N=42
#                                                    |
#                                                    |--BA.1.1_2|N=73
#                                                    |
#                                                    |--BA.1.1(BA.1/BA.1.9/BA.1.17/...[n=5])|N=959
#                                                    |
#                                                    |--BA.1.17_2|N=17
#                                                    |
#                                                    |--BA.1.17_3|N=14
#                                                    |
#                                                     \-BA.1.17_4|N=23

# %%
root_partition_node.write(format=1, outfile='n115622.outliers_removed.partitionTree.tre')

# %% [markdown]
# ### Label all nodes by partition

# %%
node_partition = {}
for p in partitions:
    for node in p.actives['tree'].traverse():
        node_partition[node.name] = p.name

# %%
with open('n115622.outliers_removed.node_partition.tsv', 'w+') as outfile:
    outfile.write('node\tpartition\n')
    outfile.write('\n'.join(['%s\t%s' % (k, v) for k, v in node_partition.items()]))

# %% [markdown]
# ### Deconstruct partition-tree into nodes/links

# %%
part_nodes = [
    {
        'id': node.name,
        'num': node.p.count,
        'type': 3,
        'divs': [
            {
                'label': k,
                'num': v['count']
            } for k, v in node.p.actives['grp_dist'].items()
        ]
    } for node in part_tree.traverse()
]

# %%
part_links = [
    {
        'id': '%s_%s' % (node.up.name if node.up else '', node.name),
        'source': node.up.name if node.up else '',
        'target': node.name,
        'len': node.dist,
    } for node in part_tree.traverse()
]
part_links = list(filter(lambda link: link['source'], part_links))

# %% [markdown]
# ### Get group distribution

# %%
with open('n115622.outliers_removed.partition_summary.tsv', 'w+') as outfile:
    for p in partitions:
        grp_dist = p.actives['grp_dist']
        total_count = sum([v['count'] for v in grp_dist.values()])
        outfile.write('%s (root: %s)\n' % (p.name, p.actives['tree'].name))
        for grp, v in grp_dist.items():
            outfile.write('%s (n=%d (%.2f%%))\n' % (grp, v['count'], (v['count']*100/total_count)))
        outfile.write('\n')

# %% [markdown]
# ## Write to file

# %%
with open('test_n1307_nodes.json', 'w+') as outfile:
    outfile.write(json.dumps(part_nodes))

# %%
with open('test_n1307_links.json', 'w+') as outfile:
    outfile.write(json.dumps(part_links))

# %%
nodes_links = {
    'nodes': part_nodes,
    'links': part_links
}
with open('test_n1307_nodes_links.json', 'w+') as outfile:
    outfile.write(json.dumps(nodes_links))
